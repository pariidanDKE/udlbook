# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-wxe77tu3
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-wxe77tu3
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /home/dan-parii/.pyenv/versions/3.12.0/envs/apple-music-kg/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (2.32.5)
# Requirement already satisfied: numpy in /home/dan-parii/Documents/udlbook/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (1.26.4)
# Requirement already satisfied: matplotlib in /home/dan-parii/.pyenv/versions/3.12.0/envs/apple-music-kg/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (3.10.9)
# Requirement already satisfied: scipy in /home/dan-parii/.pyenv/versions/3.12.0/envs/apple-music-kg/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/dan-parii/.pyenv/versions/3.12.0/envs/apple-music-kg/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/dan-parii/.pyenv/versions/3.12.0/envs/apple-music-kg/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/dan-parii/.pyenv/versions/3.12.0/envs/apple-music-kg/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/dan-parii/.pyenv/versions/3.12.0/envs/apple-music-kg/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/dan-parii/.pyenv/versions/3.12.0/envs/apple-music-kg/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /home/dan-parii/.pyenv/versions/3.12.0/envs/apple-music-kg/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/dan-parii/.pyenv/versions/3.12.0/envs/apple-music-kg/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/dan-parii/.pyenv/versions/3.12.0/envs/apple-music-kg/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/dan-parii/.pyenv/versions/3.12.0/envs/apple-music-kg/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /home/dan-parii/.pyenv/versions/3.12.0/envs/apple-music-kg/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/dan-parii/.pyenv/versions/3.12.0/envs/apple-music-kg/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dan-parii/.pyenv/versions/3.12.0/envs/apple-music-kg/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /home/dan-parii/.pyenv/versions/3.12.0/envs/apple-music-kg/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32')).to(DEVICE)
  y_train = torch.tensor(data['y'].transpose().astype('long')).to(DEVICE)
  x_test= torch.tensor(data['x_test'].astype('float32')).to(DEVICE)
  y_test = torch.tensor(data['y_test'].astype('long')).to(DEVICE)

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %% [markdown]
# The book tells us that the training loss and error get as close to zero as they can once the number of parameters equals the number of data points.
#
# 1) So once the number of parameters reaches the number of training examples, around 4000, the training error should be as close to zero as it can get. With two fully connected layers that is past a width of roughly 43.
#
# 2) Not sure. Somewhere before the number of parameters equals the number of examples, at the point where the model is not flexible enough to fit the data exactly and has to make compromises that act as implicit regularisers. So I would say a fair way before 43.
#
# 3) Same as 1, at the point where the training error first hits zero.

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    model = model.to(DEVICE)
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.303089, train error 90.07,  test loss 2.301201, test error 90.12
# Epoch   100, train loss 1.905876, train error 72.85,  test loss 1.754538, test error 69.85
# Epoch   200, train loss 1.899670, train error 72.35,  test loss 1.740992, test error 69.07
# Epoch   300, train loss 1.898275, train error 71.88,  test loss 1.732624, test error 69.52
# Epoch   400, train loss 1.899358, train error 71.43,  test loss 1.739400, test error 69.47
# Epoch   500, train loss 1.898371, train error 71.07,  test loss 1.738759, test error 69.22
# Epoch   600, train loss 1.897570, train error 70.80,  test loss 1.739743, test error 69.07
# Epoch   700, train loss 1.900096, train error 73.00,  test loss 1.729893, test error 69.72
# Epoch   800, train loss 1.898047, train error 72.18,  test loss 1.727450, test error 70.27
# Epoch   900, train loss 1.898749, train error 71.60,  test loss 1.735938, test error 69.60
# Training model with   4 hidden variables
# Epoch     0, train loss 2.302770, train error 89.65,  test loss 2.302897, test error 89.75
# Epoch   100, train loss 1.787037, train error 66.15,  test loss 1.611813, test error 62.55
# Epoch   200, train loss 1.770863, train error 65.95,  test loss 1.594201, test error 61.80
# Epoch   300, train loss 1.764508, train error 64.85,  test loss 1.600195, test error 61.52
# Epoch   400, train loss 1.763286, train error 65.47,  test loss 1.607642, test error 62.62
# Epoch   500, train loss 1.760994, train error 64.80,  test loss 1.618494, test error 62.00
# Epoch   600, train loss 1.760150, train error 64.97,  test loss 1.618309, test error 62.65
# Epoch   700, train loss 1.759917, train error 65.32,  test loss 1.615060, test error 62.42
# Epoch   800, train loss 1.762944, train error 65.27,  test loss 1.615355, test error 62.80
# Epoch   900, train loss 1.760972, train error 65.72,  test loss 1.615246, test error 63.40
# Training model with   6 hidden variables
# Epoch     0, train loss 2.264303, train error 85.35,  test loss 2.263360, test error 85.45
# Epoch   100, train loss 1.644041, train error 58.37,  test loss 1.469375, test error 55.90
# Epoch   200, train loss 1.596779, train error 55.67,  test loss 1.411406, test error 54.00
# Epoch   300, train loss 1.586217, train error 55.95,  test loss 1.405827, test error 53.70
# Epoch   400, train loss 1.579927, train error 55.85,  test loss 1.402903, test error 53.70
# Epoch   500, train loss 1.591250, train error 56.15,  test loss 1.398546, test error 52.82
# Epoch   600, train loss 1.583991, train error 56.00,  test loss 1.394659, test error 52.40
# Epoch   700, train loss 1.565307, train error 55.27,  test loss 1.372752, test error 51.90
# Epoch   800, train loss 1.560970, train error 55.70,  test loss 1.371651, test error 51.67
# Epoch   900, train loss 1.566267, train error 55.37,  test loss 1.377972, test error 51.75
# Training model with   8 hidden variables
# Epoch     0, train loss 2.291487, train error 88.75,  test loss 2.295076, test error 89.88
# Epoch   100, train loss 1.655654, train error 59.57,  test loss 1.489852, test error 58.27
# Epoch   200, train loss 1.595672, train error 57.02,  test loss 1.460839, test error 56.35
# Epoch   300, train loss 1.561019, train error 55.55,  test loss 1.438311, test error 55.15
# Epoch   400, train loss 1.544407, train error 55.12,  test loss 1.437515, test error 54.65
# Epoch   500, train loss 1.533483, train error 54.20,  test loss 1.441982, test error 55.20
# Epoch   600, train loss 1.530059, train error 53.95,  test loss 1.452412, test error 55.95
# Epoch   700, train loss 1.522065, train error 53.07,  test loss 1.451271, test error 55.52
# Epoch   800, train loss 1.521933, train error 53.27,  test loss 1.453410, test error 55.77
# Epoch   900, train loss 1.519133, train error 52.97,  test loss 1.462105, test error 55.95
# Training model with  10 hidden variables
# Epoch     0, train loss 2.238167, train error 83.88,  test loss 2.218380, test error 83.43
# Epoch   100, train loss 1.545176, train error 54.10,  test loss 1.460973, test error 55.82
# Epoch   200, train loss 1.459598, train error 50.90,  test loss 1.355419, test error 50.55
# Epoch   300, train loss 1.419092, train error 49.10,  test loss 1.330285, test error 48.90
# Epoch   400, train loss 1.398270, train error 48.50,  test loss 1.321718, test error 48.07
# Epoch   500, train loss 1.393904, train error 48.45,  test loss 1.313370, test error 48.00
# Epoch   600, train loss 1.387040, train error 47.75,  test loss 1.317057, test error 47.82
# Epoch   700, train loss 1.384215, train error 47.90,  test loss 1.326125, test error 48.82
# Epoch   800, train loss 1.383117, train error 47.42,  test loss 1.324369, test error 48.45
# Epoch   900, train loss 1.374468, train error 47.22,  test loss 1.320453, test error 48.32
# Training model with  14 hidden variables
# Epoch     0, train loss 2.249076, train error 83.30,  test loss 2.242789, test error 83.12
# Epoch   100, train loss 1.452739, train error 49.72,  test loss 1.355384, test error 51.97
# Epoch   200, train loss 1.345106, train error 45.47,  test loss 1.313242, test error 49.85
# Epoch   300, train loss 1.316599, train error 44.32,  test loss 1.352998, test error 50.97
# Epoch   400, train loss 1.290113, train error 43.77,  test loss 1.331501, test error 49.75
# Epoch   500, train loss 1.274626, train error 43.70,  test loss 1.336287, test error 50.07
# Epoch   600, train loss 1.275778, train error 43.42,  test loss 1.346842, test error 49.87
# Epoch   700, train loss 1.260846, train error 42.70,  test loss 1.354671, test error 50.25
# Epoch   800, train loss 1.254665, train error 42.42,  test loss 1.368722, test error 50.60
# Epoch   900, train loss 1.252452, train error 42.37,  test loss 1.380575, test error 50.75
# Training model with  18 hidden variables
# Epoch     0, train loss 2.257710, train error 83.95,  test loss 2.249309, test error 83.95
# Epoch   100, train loss 1.333821, train error 43.95,  test loss 1.289905, test error 46.95
# Epoch   200, train loss 1.240690, train error 41.17,  test loss 1.315822, test error 47.25
# Epoch   300, train loss 1.208521, train error 40.27,  test loss 1.365518, test error 47.70
# Epoch   400, train loss 1.183026, train error 39.27,  test loss 1.383236, test error 48.80
# Epoch   500, train loss 1.163408, train error 38.82,  test loss 1.402922, test error 48.17
# Epoch   600, train loss 1.150584, train error 38.12,  test loss 1.422643, test error 48.95
# Epoch   700, train loss 1.144838, train error 38.40,  test loss 1.439615, test error 48.50
# Epoch   800, train loss 1.140510, train error 38.00,  test loss 1.455006, test error 48.42
# Epoch   900, train loss 1.133510, train error 38.15,  test loss 1.470359, test error 48.45
# Training model with  22 hidden variables
# Epoch     0, train loss 2.203391, train error 84.20,  test loss 2.195727, test error 83.07
# Epoch   100, train loss 1.242376, train error 41.10,  test loss 1.323441, test error 49.17
# Epoch   200, train loss 1.128599, train error 37.15,  test loss 1.400678, test error 49.27
# Epoch   300, train loss 1.088347, train error 36.65,  test loss 1.487148, test error 50.65
# Epoch   400, train loss 1.054955, train error 35.27,  test loss 1.567513, test error 51.52
# Epoch   500, train loss 1.022322, train error 33.88,  test loss 1.603036, test error 51.72
# Epoch   600, train loss 1.014682, train error 34.12,  test loss 1.688659, test error 52.95
# Epoch   700, train loss 0.987058, train error 33.32,  test loss 1.744220, test error 53.50
# Epoch   800, train loss 0.974973, train error 32.50,  test loss 1.770259, test error 54.05
# Epoch   900, train loss 0.966390, train error 32.60,  test loss 1.806308, test error 53.30
# Training model with  26 hidden variables
# Epoch     0, train loss 2.162690, train error 80.53,  test loss 2.147081, test error 79.00
# Epoch   100, train loss 1.206596, train error 38.95,  test loss 1.290624, test error 46.85
# Epoch   200, train loss 1.065317, train error 34.52,  test loss 1.414148, test error 49.65
# Epoch   300, train loss 0.993359, train error 33.55,  test loss 1.539869, test error 51.15
# Epoch   400, train loss 0.948487, train error 31.38,  test loss 1.625712, test error 50.97
# Epoch   500, train loss 0.901620, train error 29.97,  test loss 1.705982, test error 52.75
# Epoch   600, train loss 0.892609, train error 29.82,  test loss 1.760220, test error 53.47
# Epoch   700, train loss 0.872610, train error 29.45,  test loss 1.815336, test error 53.80
# Epoch   800, train loss 0.878759, train error 30.00,  test loss 1.873401, test error 54.00
# Epoch   900, train loss 0.839694, train error 28.67,  test loss 1.907557, test error 53.97
# Training model with  30 hidden variables
# Epoch     0, train loss 2.124108, train error 77.97,  test loss 2.093078, test error 78.90
# Epoch   100, train loss 1.141857, train error 38.82,  test loss 1.389548, test error 51.50
# Epoch   200, train loss 0.934737, train error 31.10,  test loss 1.548218, test error 51.05
# Epoch   300, train loss 0.840698, train error 27.67,  test loss 1.739683, test error 52.32
# Epoch   400, train loss 0.795484, train error 26.82,  test loss 1.930516, test error 53.77
# Epoch   500, train loss 0.759151, train error 25.15,  test loss 2.115817, test error 55.47
# Epoch   600, train loss 0.746102, train error 25.42,  test loss 2.284810, test error 55.92
# Epoch   700, train loss 0.719139, train error 25.17,  test loss 2.451689, test error 55.00
# Epoch   800, train loss 0.692825, train error 24.72,  test loss 2.586743, test error 56.37
# Epoch   900, train loss 0.669464, train error 23.45,  test loss 2.738691, test error 56.80
# Training model with  35 hidden variables
# Epoch     0, train loss 2.094420, train error 77.50,  test loss 2.040533, test error 75.65
# Epoch   100, train loss 1.004684, train error 33.05,  test loss 1.334166, test error 48.67
# Epoch   200, train loss 0.769196, train error 25.80,  test loss 1.662381, test error 51.45
# Epoch   300, train loss 0.666760, train error 22.00,  test loss 2.000261, test error 53.00
# Epoch   400, train loss 0.578859, train error 20.05,  test loss 2.378555, test error 54.90
# Epoch   500, train loss 0.542260, train error 18.97,  test loss 2.690178, test error 55.40
# Epoch   600, train loss 0.518199, train error 17.47,  test loss 3.037354, test error 55.75
# Epoch   700, train loss 0.466832, train error 16.92,  test loss 3.266995, test error 55.05
# Epoch   800, train loss 0.453579, train error 16.17,  test loss 3.560268, test error 55.77
# Epoch   900, train loss 0.457968, train error 16.32,  test loss 3.863568, test error 55.82
# Training model with  40 hidden variables
# Epoch     0, train loss 2.094128, train error 76.88,  test loss 2.030866, test error 75.32
# Epoch   100, train loss 0.913036, train error 28.85,  test loss 1.476859, test error 50.75
# Epoch   200, train loss 0.637227, train error 20.82,  test loss 1.989982, test error 53.92
# Epoch   300, train loss 0.462850, train error 14.97,  test loss 2.745780, test error 56.92
# Epoch   400, train loss 0.404356, train error 13.67,  test loss 3.432665, test error 55.45
# Epoch   500, train loss 0.339356, train error 11.15,  test loss 4.325324, test error 57.45
# Epoch   600, train loss 0.340183, train error 11.37,  test loss 4.923584, test error 56.92
# Epoch   700, train loss 0.331382, train error 11.97,  test loss 5.846675, test error 58.60
# Epoch   800, train loss 0.265717, train error 9.40,  test loss 6.315631, test error 57.85
# Epoch   900, train loss 0.282600, train error 10.07,  test loss 6.843921, test error 58.12
# Training model with  45 hidden variables
# Epoch     0, train loss 2.068081, train error 75.95,  test loss 2.036250, test error 77.62
# Epoch   100, train loss 0.821138, train error 25.77,  test loss 1.472055, test error 49.60
# Epoch   200, train loss 0.505628, train error 16.22,  test loss 2.162312, test error 51.05
# Epoch   300, train loss 0.344174, train error 11.60,  test loss 3.144607, test error 53.50
# Epoch   400, train loss 0.227669, train error 7.05,  test loss 4.458300, test error 54.95
# Epoch   500, train loss 0.177065, train error 5.47,  test loss 5.761717, test error 55.87
# Epoch   600, train loss 0.174631, train error 6.57,  test loss 7.026747, test error 55.70
# Epoch   700, train loss 0.161059, train error 5.62,  test loss 7.896245, test error 54.72
# Epoch   800, train loss 0.008837, train error -0.00,  test loss 8.965899, test error 55.72
# Epoch   900, train loss 0.006243, train error -0.00,  test loss 9.532765, test error 55.70
# Training model with  50 hidden variables
# Epoch     0, train loss 2.102299, train error 79.03,  test loss 2.047547, test error 77.50
# Epoch   100, train loss 0.722693, train error 23.00,  test loss 1.653151, test error 52.05
# Epoch   200, train loss 0.342742, train error 10.82,  test loss 2.685539, test error 53.05
# Epoch   300, train loss 0.117504, train error 1.97,  test loss 4.274743, test error 54.52
# Epoch   400, train loss 0.027808, train error -0.00,  test loss 5.790179, test error 54.62
# Epoch   500, train loss 0.013457, train error -0.00,  test loss 6.727817, test error 54.35
# Epoch   600, train loss 0.008212, train error -0.00,  test loss 7.356747, test error 54.67
# Epoch   700, train loss 0.005930, train error -0.00,  test loss 7.818725, test error 54.85
# Epoch   800, train loss 0.004550, train error -0.00,  test loss 8.191924, test error 54.85
# Epoch   900, train loss 0.003688, train error -0.00,  test loss 8.499087, test error 54.87
# Training model with  55 hidden variables
# Epoch     0, train loss 2.103370, train error 76.80,  test loss 2.084148, test error 77.82
# Epoch   100, train loss 0.615848, train error 19.05,  test loss 1.635032, test error 51.05
# Epoch   200, train loss 0.200950, train error 4.75,  test loss 3.021106, test error 54.00
# Epoch   300, train loss 0.033368, train error -0.00,  test loss 4.698769, test error 54.15
# Epoch   400, train loss 0.013725, train error -0.00,  test loss 5.678939, test error 55.30
# Epoch   500, train loss 0.008104, train error -0.00,  test loss 6.264392, test error 55.32
# Epoch   600, train loss 0.005638, train error -0.00,  test loss 6.686714, test error 55.30
# Epoch   700, train loss 0.004237, train error -0.00,  test loss 7.023424, test error 55.22
# Epoch   800, train loss 0.003360, train error -0.00,  test loss 7.295756, test error 55.52
# Epoch   900, train loss 0.002767, train error -0.00,  test loss 7.525348, test error 55.57
# Training model with  60 hidden variables
# Epoch     0, train loss 2.052119, train error 75.95,  test loss 2.007421, test error 77.30
# Epoch   100, train loss 0.550797, train error 16.00,  test loss 1.666883, test error 50.57
# Epoch   200, train loss 0.124462, train error 1.75,  test loss 3.170530, test error 53.30
# Epoch   300, train loss 0.022479, train error -0.00,  test loss 4.552494, test error 54.50
# Epoch   400, train loss 0.010336, train error -0.00,  test loss 5.296248, test error 54.97
# Epoch   500, train loss 0.006570, train error -0.00,  test loss 5.756815, test error 54.82
# Epoch   600, train loss 0.004561, train error -0.00,  test loss 6.094510, test error 55.00
# Epoch   700, train loss 0.003497, train error -0.00,  test loss 6.365347, test error 54.92
# Epoch   800, train loss 0.002816, train error -0.00,  test loss 6.584274, test error 54.95
# Epoch   900, train loss 0.002324, train error -0.00,  test loss 6.772485, test error 55.02
# Training model with  70 hidden variables
# Epoch     0, train loss 2.049812, train error 75.28,  test loss 1.993426, test error 75.82
# Epoch   100, train loss 0.365268, train error 9.35,  test loss 1.971951, test error 52.45
# Epoch   200, train loss 0.030312, train error -0.00,  test loss 3.571312, test error 53.80
# Epoch   300, train loss 0.010410, train error -0.00,  test loss 4.324055, test error 53.95
# Epoch   400, train loss 0.005809, train error -0.00,  test loss 4.736089, test error 53.87
# Epoch   500, train loss 0.003925, train error -0.00,  test loss 5.033670, test error 53.95
# Epoch   600, train loss 0.002932, train error -0.00,  test loss 5.259088, test error 53.95
# Epoch   700, train loss 0.002307, train error -0.00,  test loss 5.443748, test error 54.10
# Epoch   800, train loss 0.001892, train error -0.00,  test loss 5.594233, test error 54.12
# Epoch   900, train loss 0.001588, train error -0.00,  test loss 5.726592, test error 54.00
# Training model with  80 hidden variables
# Epoch     0, train loss 2.007890, train error 75.95,  test loss 1.942349, test error 75.62
# Epoch   100, train loss 0.247690, train error 4.52,  test loss 2.081229, test error 51.07
# Epoch   200, train loss 0.021511, train error -0.00,  test loss 3.480007, test error 52.55
# Epoch   300, train loss 0.008497, train error -0.00,  test loss 4.060588, test error 52.67
# Epoch   400, train loss 0.004945, train error -0.00,  test loss 4.418281, test error 52.85
# Epoch   500, train loss 0.003409, train error -0.00,  test loss 4.666208, test error 52.95
# Epoch   600, train loss 0.002554, train error -0.00,  test loss 4.859543, test error 52.90
# Epoch   700, train loss 0.002023, train error -0.00,  test loss 5.016394, test error 52.75
# Epoch   800, train loss 0.001663, train error -0.00,  test loss 5.149258, test error 52.87
# Epoch   900, train loss 0.001404, train error -0.00,  test loss 5.264034, test error 52.72
# Training model with  90 hidden variables
# Epoch     0, train loss 2.032715, train error 75.97,  test loss 1.982685, test error 75.60
# Epoch   100, train loss 0.126478, train error 0.90,  test loss 2.290683, test error 52.10
# Epoch   200, train loss 0.013736, train error -0.00,  test loss 3.277080, test error 51.82
# Epoch   300, train loss 0.006199, train error -0.00,  test loss 3.700068, test error 52.10
# Epoch   400, train loss 0.003816, train error -0.00,  test loss 3.958515, test error 52.17
# Epoch   500, train loss 0.002698, train error -0.00,  test loss 4.149559, test error 52.25
# Epoch   600, train loss 0.002059, train error -0.00,  test loss 4.300455, test error 52.30
# Epoch   700, train loss 0.001650, train error -0.00,  test loss 4.421881, test error 52.32
# Epoch   800, train loss 0.001367, train error -0.00,  test loss 4.526335, test error 52.40
# Epoch   900, train loss 0.001162, train error -0.00,  test loss 4.616170, test error 52.35
# Training model with 100 hidden variables
# Epoch     0, train loss 2.009814, train error 75.97,  test loss 1.960890, test error 76.25
# Epoch   100, train loss 0.091539, train error 0.10,  test loss 2.220161, test error 51.05
# Epoch   200, train loss 0.011946, train error -0.00,  test loss 3.084603, test error 51.22
# Epoch   300, train loss 0.005514, train error -0.00,  test loss 3.446102, test error 51.52
# Epoch   400, train loss 0.003450, train error -0.00,  test loss 3.675145, test error 51.67
# Epoch   500, train loss 0.002451, train error -0.00,  test loss 3.839460, test error 51.50
# Epoch   600, train loss 0.001878, train error -0.00,  test loss 3.969630, test error 51.52
# Epoch   700, train loss 0.001507, train error -0.00,  test loss 4.074482, test error 51.55
# Epoch   800, train loss 0.001253, train error -0.00,  test loss 4.165581, test error 51.55
# Epoch   900, train loss 0.001066, train error -0.00,  test loss 4.243851, test error 51.57
# Training model with 120 hidden variables
# Epoch     0, train loss 1.958890, train error 72.65,  test loss 1.902970, test error 73.30
# Epoch   100, train loss 0.047150, train error -0.00,  test loss 2.167919, test error 49.32
# Epoch   200, train loss 0.009336, train error -0.00,  test loss 2.760949, test error 49.17
# Epoch   300, train loss 0.004645, train error -0.00,  test loss 3.031732, test error 49.32
# Epoch   400, train loss 0.002988, train error -0.00,  test loss 3.206911, test error 49.50
# Epoch   500, train loss 0.002156, train error -0.00,  test loss 3.335478, test error 49.45
# Epoch   600, train loss 0.001668, train error -0.00,  test loss 3.436501, test error 49.52
# Epoch   700, train loss 0.001349, train error -0.00,  test loss 3.520539, test error 49.50
# Epoch   800, train loss 0.001127, train error -0.00,  test loss 3.592368, test error 49.55
# Epoch   900, train loss 0.000963, train error -0.00,  test loss 3.654433, test error 49.60
# Training model with 140 hidden variables
# Epoch     0, train loss 1.959146, train error 73.07,  test loss 1.886342, test error 74.32
# Epoch   100, train loss 0.034528, train error -0.00,  test loss 2.201218, test error 49.32
# Epoch   200, train loss 0.008020, train error -0.00,  test loss 2.680615, test error 49.55
# Epoch   300, train loss 0.004139, train error -0.00,  test loss 2.914380, test error 49.60
# Epoch   400, train loss 0.002695, train error -0.00,  test loss 3.063603, test error 49.75
# Epoch   500, train loss 0.001961, train error -0.00,  test loss 3.175966, test error 49.77
# Epoch   600, train loss 0.001525, train error -0.00,  test loss 3.265319, test error 49.70
# Epoch   700, train loss 0.001239, train error -0.00,  test loss 3.338988, test error 49.70
# Epoch   800, train loss 0.001038, train error -0.00,  test loss 3.402454, test error 49.67
# Epoch   900, train loss 0.000890, train error -0.00,  test loss 3.457709, test error 49.65
# Training model with 160 hidden variables
# Epoch     0, train loss 1.943420, train error 72.75,  test loss 1.863829, test error 73.15
# Epoch   100, train loss 0.028224, train error -0.00,  test loss 2.130830, test error 49.67
# Epoch   200, train loss 0.007078, train error -0.00,  test loss 2.550192, test error 49.85
# Epoch   300, train loss 0.003724, train error -0.00,  test loss 2.751769, test error 49.87
# Epoch   400, train loss 0.002435, train error -0.00,  test loss 2.883236, test error 49.75
# Epoch   500, train loss 0.001784, train error -0.00,  test loss 2.984510, test error 49.80
# Epoch   600, train loss 0.001393, train error -0.00,  test loss 3.064730, test error 49.75
# Epoch   700, train loss 0.001134, train error -0.00,  test loss 3.131818, test error 49.77
# Epoch   800, train loss 0.000952, train error -0.00,  test loss 3.189261, test error 49.72
# Epoch   900, train loss 0.000818, train error -0.00,  test loss 3.239542, test error 49.77
# Training model with 180 hidden variables
# Epoch     0, train loss 1.915094, train error 70.57,  test loss 1.855620, test error 71.88
# Epoch   100, train loss 0.023786, train error -0.00,  test loss 2.059187, test error 48.92
# Epoch   200, train loss 0.006492, train error -0.00,  test loss 2.400775, test error 49.00
# Epoch   300, train loss 0.003487, train error -0.00,  test loss 2.574700, test error 49.17
# Epoch   400, train loss 0.002315, train error -0.00,  test loss 2.691142, test error 49.22
# Epoch   500, train loss 0.001703, train error -0.00,  test loss 2.779100, test error 49.37
# Epoch   600, train loss 0.001335, train error -0.00,  test loss 2.849748, test error 49.45
# Epoch   700, train loss 0.001090, train error -0.00,  test loss 2.909220, test error 49.45
# Epoch   800, train loss 0.000916, train error -0.00,  test loss 2.959739, test error 49.45
# Epoch   900, train loss 0.000787, train error -0.00,  test loss 3.003700, test error 49.40
# Training model with 200 hidden variables
# Epoch     0, train loss 1.919943, train error 69.57,  test loss 1.839894, test error 72.25
# Epoch   100, train loss 0.021262, train error -0.00,  test loss 2.023729, test error 47.47
# Epoch   200, train loss 0.006051, train error -0.00,  test loss 2.341329, test error 47.62
# Epoch   300, train loss 0.003291, train error -0.00,  test loss 2.506244, test error 47.55
# Epoch   400, train loss 0.002200, train error -0.00,  test loss 2.616417, test error 47.47
# Epoch   500, train loss 0.001626, train error -0.00,  test loss 2.700420, test error 47.55
# Epoch   600, train loss 0.001277, train error -0.00,  test loss 2.767701, test error 47.62
# Epoch   700, train loss 0.001045, train error -0.00,  test loss 2.823518, test error 47.55
# Epoch   800, train loss 0.000880, train error -0.00,  test loss 2.871816, test error 47.52
# Epoch   900, train loss 0.000757, train error -0.00,  test loss 2.913597, test error 47.60
# Training model with 250 hidden variables
# Epoch     0, train loss 1.936398, train error 71.50,  test loss 1.869593, test error 71.70
# Epoch   100, train loss 0.017170, train error -0.00,  test loss 1.921350, test error 47.20
# Epoch   200, train loss 0.005355, train error -0.00,  test loss 2.171695, test error 47.02
# Epoch   300, train loss 0.002967, train error -0.00,  test loss 2.304159, test error 47.02
# Epoch   400, train loss 0.002001, train error -0.00,  test loss 2.394000, test error 46.85
# Epoch   500, train loss 0.001487, train error -0.00,  test loss 2.463561, test error 46.77
# Epoch   600, train loss 0.001172, train error -0.00,  test loss 2.519247, test error 46.87
# Epoch   700, train loss 0.000962, train error -0.00,  test loss 2.565098, test error 46.82
# Epoch   800, train loss 0.000813, train error -0.00,  test loss 2.605397, test error 47.05
# Epoch   900, train loss 0.000701, train error -0.00,  test loss 2.640340, test error 47.05
# Training model with 300 hidden variables
# Epoch     0, train loss 1.875524, train error 67.90,  test loss 1.812685, test error 69.88
# Epoch   100, train loss 0.014308, train error -0.00,  test loss 1.863008, test error 47.22
# Epoch   200, train loss 0.004773, train error -0.00,  test loss 2.076353, test error 46.80
# Epoch   300, train loss 0.002710, train error -0.00,  test loss 2.191771, test error 46.57
# Epoch   400, train loss 0.001846, train error -0.00,  test loss 2.269911, test error 46.62
# Epoch   500, train loss 0.001383, train error -0.00,  test loss 2.330983, test error 46.70
# Epoch   600, train loss 0.001096, train error -0.00,  test loss 2.380840, test error 46.72
# Epoch   700, train loss 0.000902, train error -0.00,  test loss 2.422091, test error 46.65
# Epoch   800, train loss 0.000764, train error -0.00,  test loss 2.457564, test error 46.70
# Epoch   900, train loss 0.000660, train error -0.00,  test loss 2.488906, test error 46.65
# Training model with 400 hidden variables
# Epoch     0, train loss 1.833686, train error 66.20,  test loss 1.753762, test error 67.77
# Epoch   100, train loss 0.011836, train error -0.00,  test loss 1.756946, test error 44.32
# Epoch   200, train loss 0.004212, train error -0.00,  test loss 1.935539, test error 44.47
# Epoch   300, train loss 0.002435, train error -0.00,  test loss 2.034273, test error 44.30
# Epoch   400, train loss 0.001676, train error -0.00,  test loss 2.102517, test error 44.40
# Epoch   500, train loss 0.001263, train error -0.00,  test loss 2.154242, test error 44.22
# Epoch   600, train loss 0.001005, train error -0.00,  test loss 2.196366, test error 44.25
# Epoch   700, train loss 0.000831, train error -0.00,  test loss 2.232661, test error 44.15
# Epoch   800, train loss 0.000705, train error -0.00,  test loss 2.263365, test error 44.07
# Epoch   900, train loss 0.000611, train error -0.00,  test loss 2.290494, test error 44.10

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
